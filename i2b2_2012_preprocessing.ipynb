# %% [markdown]
# ## Step 1: convert xml to BRAT
# Code from Xi Yang (University of Florida)
#
# Modified by Lavender Jiang

# %%
import shutil
from pathlib import Path
import xmltodict
import os
import sys
from collections import defaultdict
import numpy as np
import pathlib

# %%
# folder for raw files
infiles = {"train": "/gpfs/data/oermannlab/public_data/i2b2_2012/2012-07-15.original-annotation.release",
           "test": "/gpfs/data/oermannlab/public_data/i2b2_2012/2012-08-08.test-data.event-timex-groundtruth/xml"}

brat_out = {"train": "brat-train",
            "test": "brat-test"}

def get_paths(d, keys):
    ptr = {}
    for key in keys:
        ptr[key] = Path(d[key])
    return ptr

def make_dir(d):
    print("making dir...")
    for key in d.keys():
        path = d[key]
        if not type(path) == pathlib.PosixPath:
            path = Path(path)
        path.mkdir(parents=True, exist_ok=True)            

splits = ["train", "test"]
in_paths = get_paths(infiles, splits)
out_paths = get_paths(brat_out, splits)
make_dir(out_paths)
# Out:
# making dir...

# %%
def copy_text(d_src, d_dest):
    for key in d_src:
        path_src = d_src[key]
        path_dest = d_dest[key]
        print(f"copying text for split {key}. source path {path_src}, dest path {path_dest}")
        gen = path_src.glob("*.txt")
        if len(list(gen)) == 0:
            raise RunTimeError(f"empty directory! please make sure you have .txt file in {path_src}")
        for each in path_src.glob("*.txt"):
            fid = each.stem.split(".")[0]
            new_file = path_dest / f"{fid}.txt"
            shutil.copyfile(each, new_file)
            print(f"copied doc {fid} to {new_file}")

copy_text(in_paths, out_paths)
# Out:
# copying text for split train. source path /gpfs/data/oermannlab/public_data/i2b2_2012/2012-07-15.original-annotation.release, dest path brat-train
# copied doc 471 to brat-train/471.txt
# copied doc 596 to brat-train/596.txt
# copied doc 26 to brat-train/26.txt
# copied doc 192 to brat-train/192.txt
# copied doc 541 to brat-train/541.txt
# copied doc 682 to brat-train/682.txt
# copied doc 492 to brat-train/492.txt
# copied doc 331 to brat-train/331.txt
# copied doc 376 to brat-train/376.txt
# copied doc 86 to brat-train/86.txt
# copied doc 747 to brat-train/747.txt
# copied doc 776 to brat-train/776.txt
# copied doc 193 to brat-train/193.txt
# copied doc 462 to brat-train/462.txt
# copied doc 497 to brat-train/497.txt
# copied doc 11 to brat-train/11.txt
# copied doc 343 to brat-train/343.txt
# copied doc 307 to brat-train/307.txt
# copied doc 353 to brat-train/353.txt
# copied doc 267 to brat-train/267.txt
# copied doc 172 to brat-train/172.txt
# copied doc 636 to brat-train/636.txt
# copied doc 356 to brat-train/356.txt
# copied doc 191 to brat-train/191.txt
# copied doc 751 to brat-train/751.txt
# copied doc 256 to brat-train/256.txt
# copied doc 237 to brat-train/237.txt
# copied doc 121 to brat-train/121.txt
# copied doc 301 to brat-train/301.txt
# copied doc 6 to brat-train/6.txt
# copied doc 526 to brat-train/526.txt
# copied doc 676 to brat-train/676.txt
# copied doc 413 to brat-train/413.txt
# copied doc 252 to brat-train/252.txt
# copied doc 642 to brat-train/642.txt
# copied doc 151 to brat-train/151.txt
# copied doc 321 to brat-train/321.txt
# copied doc 707 to brat-train/707.txt
# copied doc 318 to brat-train/318.txt
# copied doc 458 to brat-train/458.txt
# copied doc 96 to brat-train/96.txt
# copied doc 612 to brat-train/612.txt
# copied doc 522 to brat-train/522.txt
# copied doc 351 to brat-train/351.txt
# copied doc 611 to brat-train/611.txt
# copied doc 47 to brat-train/47.txt
# copied doc 273 to brat-train/273.txt
# copied doc 637 to brat-train/637.txt
# copied doc 302 to brat-train/302.txt
# copied doc 291 to brat-train/291.txt
# copied doc 571 to brat-train/571.txt
# copied doc 452 to brat-train/452.txt
# copied doc 622 to brat-train/622.txt
# copied doc 218 to brat-train/218.txt
# copied doc 2 to brat-train/2.txt
# copied doc 1 to brat-train/1.txt
# copied doc 641 to brat-train/641.txt
# copied doc 92 to brat-train/92.txt
# copied doc 141 to brat-train/141.txt
# copied doc 426 to brat-train/426.txt
# copied doc 427 to brat-train/427.txt
# copied doc 186 to brat-train/186.txt
# copied doc 587 to brat-train/587.txt
# copied doc 388 to brat-train/388.txt
# copied doc 736 to brat-train/736.txt
# copied doc 626 to brat-train/626.txt
# copied doc 152 to brat-train/152.txt
# copied doc 42 to brat-train/42.txt
# copied doc 386 to brat-train/386.txt
# copied doc 577 to brat-train/577.txt
# copied doc 72 to brat-train/72.txt
# copied doc 756 to brat-train/756.txt
# copied doc 722 to brat-train/722.txt
# copied doc 791 to brat-train/791.txt
# copied doc 432 to brat-train/432.txt
# copied doc 143 to brat-train/143.txt
# copied doc 93 to brat-train/93.txt
# copied doc 433 to brat-train/433.txt
# copied doc 167 to brat-train/167.txt
# copied doc 197 to brat-train/197.txt
# copied doc 692 to brat-train/692.txt
# copied doc 236 to brat-train/236.txt
# copied doc 393 to brat-train/393.txt
# copied doc 313 to brat-train/313.txt
# copied doc 153 to brat-train/153.txt
# copied doc 496 to brat-train/496.txt
# copied doc 717 to brat-train/717.txt
# copied doc 481 to brat-train/481.txt
# copied doc 468 to brat-train/468.txt
# copied doc 396 to brat-train/396.txt
# copied doc 807 to brat-train/807.txt
# copied doc 122 to brat-train/122.txt
# copied doc 81 to brat-train/81.txt
# copied doc 178 to brat-train/178.txt
# copied doc 3 to brat-train/3.txt
# copied doc 591 to brat-train/591.txt
# copied doc 373 to brat-train/373.txt
# copied doc 557 to brat-train/557.txt
# copied doc 188 to brat-train/188.txt
# copied doc 43 to brat-train/43.txt
# copied doc 382 to brat-train/382.txt
# copied doc 532 to brat-train/532.txt
# copied doc 491 to brat-train/491.txt
# copied doc 582 to brat-train/582.txt
# copied doc 336 to brat-train/336.txt
# copied doc 362 to brat-train/362.txt
# copied doc 346 to brat-train/346.txt
# copied doc 721 to brat-train/721.txt
# copied doc 787 to brat-train/787.txt
# copied doc 417 to brat-train/417.txt
# copied doc 21 to brat-train/21.txt
# copied doc 567 to brat-train/567.txt
# copied doc 166 to brat-train/166.txt
# copied doc 23 to brat-train/23.txt
# copied doc 576 to brat-train/576.txt
# copied doc 107 to brat-train/107.txt
# copied doc 521 to brat-train/521.txt
# copied doc 367 to brat-train/367.txt
# copied doc 308 to brat-train/308.txt
# copied doc 511 to brat-train/511.txt
# copied doc 272 to brat-train/272.txt
# copied doc 786 to brat-train/786.txt
# copied doc 697 to brat-train/697.txt
# copied doc 387 to brat-train/387.txt
# copied doc 656 to brat-train/656.txt
# copied doc 51 to brat-train/51.txt
# copied doc 123 to brat-train/123.txt
# copied doc 463 to brat-train/463.txt
# copied doc 36 to brat-train/36.txt
# copied doc 482 to brat-train/482.txt
# copied doc 68 to brat-train/68.txt
# copied doc 332 to brat-train/332.txt
# copied doc 437 to brat-train/437.txt
# copied doc 247 to brat-train/247.txt
# copied doc 512 to brat-train/512.txt
# copied doc 681 to brat-train/681.txt
# copied doc 337 to brat-train/337.txt
# copied doc 162 to brat-train/162.txt
# copied doc 602 to brat-train/602.txt
# copied doc 348 to brat-train/348.txt
# copied doc 18 to brat-train/18.txt
# copied doc 87 to brat-train/87.txt
# copied doc 366 to brat-train/366.txt
# copied doc 311 to brat-train/311.txt
# copied doc 517 to brat-train/517.txt
# copied doc 357 to brat-train/357.txt
# copied doc 201 to brat-train/201.txt
# copied doc 28 to brat-train/28.txt
# copied doc 316 to brat-train/316.txt
# copied doc 438 to brat-train/438.txt
# copied doc 411 to brat-train/411.txt
# copied doc 168 to brat-train/168.txt
# copied doc 726 to brat-train/726.txt
# copied doc 701 to brat-train/701.txt
# copied doc 8 to brat-train/8.txt
# copied doc 711 to brat-train/711.txt
# copied doc 156 to brat-train/156.txt
# copied doc 502 to brat-train/502.txt
# copied doc 422 to brat-train/422.txt
# copied doc 647 to brat-train/647.txt
# copied doc 163 to brat-train/163.txt
# copied doc 16 to brat-train/16.txt
# copied doc 408 to brat-train/408.txt
# copied doc 38 to brat-train/38.txt
# copied doc 801 to brat-train/801.txt
# copied doc 212 to brat-train/212.txt
# copied doc 423 to brat-train/423.txt
# copied doc 472 to brat-train/472.txt
# copied doc 216 to brat-train/216.txt
# copied doc 126 to brat-train/126.txt
# copied doc 631 to brat-train/631.txt
# copied doc 546 to brat-train/546.txt
# copied doc 242 to brat-train/242.txt
# copied doc 777 to brat-train/777.txt
# copied doc 213 to brat-train/213.txt
# copied doc 271 to brat-train/271.txt
# copied doc 173 to brat-train/173.txt
# copied doc 473 to brat-train/473.txt
# copied doc 757 to brat-train/757.txt
# copied doc 248 to brat-train/248.txt
# copied doc 547 to brat-train/547.txt
# copied doc 203 to brat-train/203.txt
# copied doc 572 to brat-train/572.txt
# copied doc 116 to brat-train/116.txt
# copied doc 666 to brat-train/666.txt
# copied doc 182 to brat-train/182.txt
# copied doc 352 to brat-train/352.txt
# copied doc 407 to brat-train/407.txt
# copied doc 177 to brat-train/177.txt
# copied doc 797 to brat-train/797.txt
# copied doc 98 to brat-train/98.txt
# copying text for split test. source path /gpfs/data/oermannlab/public_data/i2b2_2012/2012-08-08.test-data.event-timex-groundtruth/x
# copied doc 296 to brat-test/296.txt
# copied doc 108 to brat-test/108.txt
# copied doc 716 to brat-test/716.txt
# copied doc 71 to brat-test/71.txt
# copied doc 46 to brat-test/46.txt
# copied doc 223 to brat-test/223.txt
# copied doc 772 to brat-test/772.txt
# copied doc 257 to brat-test/257.txt
# copied doc 142 to brat-test/142.txt
# copied doc 277 to brat-test/277.txt
# copied doc 677 to brat-test/677.txt
# copied doc 796 to brat-test/796.txt
# copied doc 258 to brat-test/258.txt
# copied doc 727 to brat-test/727.txt
# copied doc 378 to brat-test/378.txt
# copied doc 103 to brat-test/103.txt
# copied doc 113 to brat-test/113.txt
# copied doc 447 to brat-test/447.txt
# copied doc 742 to brat-test/742.txt
# copied doc 127 to brat-test/127.txt
# copied doc 412 to brat-test/412.txt
# copied doc 276 to brat-test/276.txt
# copied doc 398 to brat-test/398.txt
# copied doc 101 to brat-test/101.txt
# copied doc 627 to brat-test/627.txt
# copied doc 802 to brat-test/802.txt
# copied doc 436 to brat-test/436.txt
# copied doc 552 to brat-test/552.txt
# copied doc 303 to brat-test/303.txt
# copied doc 446 to brat-test/446.txt
# copied doc 817 to brat-test/817.txt
# copied doc 157 to brat-test/157.txt
# copied doc 537 to brat-test/537.txt
# copied doc 342 to brat-test/342.txt
# copied doc 243 to brat-test/243.txt
# copied doc 391 to brat-test/391.txt
# copied doc 732 to brat-test/732.txt
# copied doc 466 to brat-test/466.txt
# copied doc 202 to brat-test/202.txt
# copied doc 131 to brat-test/131.txt

# %%
BRAT_TEMP = "T{}\t{} {} {}\t{}"
EVENTS = {'PROBLEM', 'TEST', 'TREATMENT', 'CLINICAL_DEPT', 'EVIDENTIAL', 'OCCURRENCE'}
SPEC = {'&': 'AAMMPP'}

def load_file(file):
    with open(file, "r") as f:
        cont = f.read()
    return cont

def write_to_file(data, file):
    with open(file, "w") as f:
        f.write(data)

def xml2brat(p1, p2, verbose=False):
    # offset need to -1 on the number
    for each in p1.glob("*.xml"):
        brat_anns = []
        idx = 1
        print(f'file name is {each}')
        ofn = p2 / (each.stem.split(".")[0] + ".ann")
        xml = load_file(each)
        if verbose:
            print(xml)
        xml = xml.replace('&', 'AAMMPP')
        tags = xmltodict.parse(xml)['ClinicalNarrativeTemporalAnnotation']['TAGS']
        try:
            for k, v in tags.items():
                # only keep event tags
                if k == 'EVENT':
                    for d in v:
                        typ = d['@type']
                        if typ in EVENTS:
                            s = int(d['@start']) - 1 # convert from 1-index to 0-index
                            e = int(d['@end']) - 1
                            txt = d['@text']
                            brat_anns.append(BRAT_TEMP.format(idx, typ, s, e, txt))
                            idx += 1
        except:
            print(xml)
            print(tags)
            assert(False)
        ot = "\n".join(brat_anns)
        ot = ot.replace('AAMMPP', '&')
        # break # added for debug
        write_to_file(ot, ofn)

def dataset_xml2brat(d_in, d_out):
    for key in d_in:
        print(f"in path is {d_in[key]}, out path is {d_out[key]}")
        xml2brat(d_in[key], d_out[key])

# %%
dataset_xml2brat(in_paths, out_paths)
# Out:
# in path is /gpfs/data/oermannlab/public_data/i2b2_2012/2012-07-15.original-annotation.
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
from shutil import copyfile
import csv

# %%
from spacy.lang.en import English
nlp = English()
sentencizer = nlp.create_pipe("sentencizer")
nlp.add_pipe("sentencizer")

# %%
# folder for brat files
infiles = {"train": "brat-train",
           "test": "brat-test"}
bio_out = {"train": "bio-train",
           "test": "bio-test"}

def get_ann_files(d_path, splits):
    res = {}
    for key in splits:
        in_path = d_path[key]
        inputfiles = set()
        for f in os.listdir(in_path):
            if f.endswith('.ann'):
                inputfiles.add(f.split('.')[0].split('_')[0])
        res[key] = inputfiles
    return res

ann_files_d = get_ann_files(infiles, ["train", "test"])
make_dir(bio_out)
# Out:
# making dir...

# %%
# list of entities to retain
select_types = ['PROBLEM', 'TEST', 'TREATMENT', 'CLINICAL_DEPT', 'EVIDENTIAL', 'OCCURRENCE']

# convert Brat format into BIO format
# function for getting entity annotations from the annotation file
def get_annotation_entities(ann_file, select_types=None):
    entities = []
    with open(ann_file, "r", encoding="utf-8") as f:
        for line in f:
            if line.startswith('T'):
                term = line.strip().split('\t')[1].split()
                if (select_types != None) and (term[0] not in select_types): continue
                if int(term[-1]) <= int(term[1]): continue
                entities.append((int(term[1]), int(term[-1]), term[0]))
    return sorted(entities, key=lambda x: (x[0], x[1]))

# function for handling overlap by keeping the entity with largest text span
def remove_overlap_entities(sorted_entities):
    keep_entities = []
    for idx, entity in enumerate(sorted_entities):
        if idx == 0:
            keep_entities.append(entity)
            last_keep = entity
            continue
        if entity[0] < last_keep[1]:
            if entity[1]-entity[0] > last_keep[1]-last_keep[0]:
                last_keep = entity
                keep_entities[-1] = last_keep
        elif entity[0] == last_keep[1]:
            last_keep = (last_keep[0], entity[1], last_keep[-1])
            keep_entities[-1] = last_keep
        else:
            last_keep = entity
            keep_entities.append(entity)
    return keep_entities

# inverse index of entity annotations
def entity_dictionary(keep_entities, txt_file):
    #print(f"txt_file is {txt_file}")
    file_name = os.path.basename(txt_file)
    #print(f"file name is {file_name}")
    f_ann = {}
    with open(txt_file, "r", encoding="utf-8") as f:
        text = f.readlines()
        text = ''.join([i for i in text])
    for entity in keep_entities:
        entity_text = text[entity[0]:entity[1]]
        doc = nlp(entity_text)
        token_starts = [(i, doc[i:].start_char) for i in range(len(doc))]
        term_type = entity[-1]
        term_offset = entity[0]
        for i, token in enumerate(doc):
            ann_offset = token_starts[i][1]+term_offset
            if ann_offset not in f_ann:
                f_ann[ann_offset] = [i, token.text, term_type]
    return f_ann

# %%
def brat2bio(inputfiles, inputpath, outputpath, verbose=False):
    # Brat -> BIO format conversion
    print(f"converting brat2bio {inputfiles}")
    for infile in inputfiles:
        file = f"{infile}"
        ann_file = f"{inputpath}/{file}.ann"
        txt_file = f"{inputpath}/{file}.txt"
        out_file = f"{outputpath}/{file}.bio.txt"
        if verbose:
            print(f'infile is {infile}')
            print(f'outfile is {out_file}')
        sorted_entities = get_annotation_entities(ann_file, select_types)
        keep_entities = remove_overlap_entities(sorted_entities)
        f_ann = entity_dictionary(keep_entities, txt_file)
        
        with open(out_file, "w", encoding="utf-8") as f_out:
            with open(txt_file, "r", encoding="utf-8") as f:
                sent_offset = 0
                prev_label = "O"
                for line in f:
                    if '⁄' in line:
                        line = line.replace('⁄', '/') # replace non unicode characters
                    doc = nlp(line.strip())
                    # list of tuples, first value is token index, second value is char idx
                    token_starts = [(i, doc[i:].start_char) for i in range(len(doc))]
                    for token in doc:
                        token_sent_offset = token_starts[token.i][1] # sentence level local index
                        token_doc_offset = token_starts[token.i][1] + sent_offset # document level global index
                        if token_doc_offset in f_ann:
                            if prev_label == "O" or not (prev_label.split("-")[1] == f_ann[token_doc_offset][2]): # or prev_label == f"I-{f_ann[token_doc_offset][2]}" or prev_label == f"B-{f_ann[token_doc_offset][2]}":#f_ann[token_doc_offset][0] == 0: # changed edge case to I-tag according to wikipedia
                                label = f"B-{f_ann[token_doc_offset][2]}"
                            else:
                                label = f"I-{f_ann[token_doc_offset][2]}"
                            if not (f_ann[token_doc_offset][1] == token.text_with_ws.rstrip()):
                                print('{} does not match {}'.format(f_ann[token_doc_offset][1], token.text_with_ws.rstrip()))
                                assert(False)
                        else:
                            label = f"O"
                        prev_label = label # update prev_label
                        f_out.write(f"{token.text} {token_sent_offset} {token_sent_offset+len(token.text)} {token_doc_offset} {token_doc_offset+len(token.text)} {label}\n")
                    f_out.write('\n')
                    sent_offset += (len(line))  

def brat2bio_dict(ann_files_d, infiles_d, bio_out_d):
    for key in ann_files_d:
        ann_file = ann_files_d[key]
        infiles = infiles_d[key]
        bio_out = bio_out_d[key]
        brat2bio(ann_file, infiles, bio_out)

# %%
brat2bio_dict(ann_files_d, infiles, bio_out)
# Out:
# converting brat2bio {'273', '247', '308', '722', '252', '366', '422', '676', '96', '462', '721', '42', '577', '302', '472', '726', '346', '337', '321', '496', '491', '72', '313', '291', '426', '386', '116', '212', '152', '517', '612', '756', '36', '791', '236', '458', '123', '191', '681', '272', '482', '173', '156', '237', '201', '332', '86', '666', '168', '502', '107', '411', '1', '582', '432', '193', '407', '433', '717', '576', '636', '427', '417', '188', '786', '167', '126', '697', '512', '248', '348', '622', '777', '707', '166', '186', '522', '481', '6', '16', '757', '637', '492', '311', '367', '801', '642', '471', '256', '438', '192', '611', '682', '271', '357', '307', '807', '81', '388', '413', '547', '38', '242', '647', '92', '23', '2', '596', '318', '177', '316', '736', '151', '93', '47', '343', '203', '396', '182', '51', '8', '352', '373', '121', '153', '218', '452', '546', '701', '656', '141', '98', '521', '797', '497', '331', '26', '336', '382', '68', '163', '353', '437', '387', '747', '43', '18', '11', '541', '532', '356', '776', '122', '473', '87', '162', '216', '28', '172', '572', '463', '631', '626', '591', '751', '178', '641', '267', '143', '393', '468', '692', '362', '511', '526', '587', '423', '408', '3', '602', '351', '571', '376', '787', '711', '567', '557', '213', '197', '301'}
# converting brat2bio {'416', '287', '627', '282', '562', '297', '326', '303', '667', '727', '233', '196', '581', '617', '66', '441', '157', '298', '592', '127', '487', '206', '262', '556', '113', '137', '802', '397', '392', '71', '361', '53', '258', '132', '446', '276', '402', '716', '333', '238', '138', '732', '466', '142', '442', '31', '812', '371', '103', '431', '358', '243', '412', '742', '131', '767', '312', '516', '261', '752', '78', '383', '227', '762', '652', '561', '21', '368', '552', '61', '83', '772', '436', '542', '128', '347', '378', '221', '293', '607', '398', '296', '712', '253', '327', '208', '342', '391', '223', '88', '73', '317', '601', '657', '806', '288', '277', '537', '817', '108', '257', '32', '207', '33', '46', '283', '677', '118', '781', '792', '447', '101', '527', '202', '222', '687', '737', '263', '171', '796'}

# %% [markdown]
# ## Step 3: Combine files to dataset

# %%
import random 

random_state = 13
train_ids, dev_ids = train_test_split(list(ann_files_d['train']), train_size=0.7, random_state=random_state, shuffle=True)
test_ids = list(ann_files_d['test'])
random.Random(random_state).shuffle(test_ids)
print(f"train size {len(train_ids)}, val size {len(dev_ids)}, test size {len(test_ids)}")
i2b2_datasets = {"train":train_ids, "dev":dev_ids, "test":test_ids}
json.dump(i2b2_datasets, open("i2b2_2012_datasets.json", "w", encoding="utf-8"))
# Out:
# train size 133, val size 57, test size 120

# %%
def make_if_nonexist(dir_s):
    if not os.path.exists(dir_s):
        os.makedirs(dir_s)

data_dir = "dataset"
make_if_nonexist(data_dir)

# Merge BIO format train, validation and test datasets
for split in ["train", "dev", "test"]:
    if split in ["train", "dev"]:
        outputpath = bio_out["train"]
    else:
        outputpath = bio_out["test"]
    split_dir = os.path.join(data_dir, split)
    make_if_nonexist(split_dir)
    with open(os.path.join(data_dir, f"{split}.txt"), "w", encoding="utf-8") as f:
        for fid in i2b2_datasets[split]:
            copyfile(f"{outputpath}/{fid}.bio.txt", os.path.join(split_dir,f"{fid}.bio.txt"))
            with open(f"{outputpath}/{fid}.bio.txt", "r", encoding="utf-8") as fr:
                txt = fr.read().strip()
                if txt != '':
                    f.write(txt)
                    f.write("\n\n")

# %% [markdown]
# ## Step 4: Bio 2 Nemo
# Code from nVidia NeMo

# %%
# !python bio2nemo.py --data_file dataset/train.txt
# Out:
# [NeMo I 2022-05-06 13:10:54 bio2nemo:119] Processing dataset/train.txt
# [NeMo I 2022-05-06 13:10:54 bio2nemo:124] Processing of the dataset/train.txt is complete

# %%
# !python bio2nemo.py --data_file dataset/dev.txt
# Out:
# [NeMo I 2022-05-06 13:11:51 bio2nemo:119] Processing dataset/dev.txt
# [NeMo I 2022-05-06 13:11:51 bio2nemo:124] Processing of the dataset/dev.txt is complete

# %%
# !python bio2nemo.py --data_file dataset/test.txt
# Out:
# [NeMo I 2022-05-06 13:11:57 bio2nemo:119] Processing dataset/test.txt
# [NeMo I 2022-05-06 13:11:58 bio2nemo:124] Processing of the dataset/test.txt is complete
